# %% [markdown]
# <h1 style="text-align: center;">Tennis Analyzer ML Model V2</h1>
# <h3 style="text-align: center;">Dan Warnick</h3>

# %% [markdown]
# <p>To start we will begin by selecting the data points we want to analyze with existing known results. For each data entry we will have two players each with the following data entries.</p>
# <table style="font-size: .8em;">
#     <tr>
#         <th>Player Name</th>
#     </tr>
# </table>
# <p>Along with match facts like Clay/Hard/Grass Court or Indoor/Outdoor. In the future may want to add weather and adjust certain parameters for more accuracy and more data points to train from, however for now this seems a good start.</p>

# %% [markdown]
# <h2>1.) Collect Data Efficiently</h2>

# %%
import django
from django.http import HttpResponse
from django.template import loader
import os
from django.db import models
import torch
from math import ceil, floor
import math
import numpy as np
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as data
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.utils as utils
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm
from datetime import datetime
from asgiref.sync import sync_to_async # type: ignore
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.metrics import roc_curve, roc_auc_score
import copy
import joblib

# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'breakpoint.settings')
# django.setup()

# from render.models import *

# %%
start = '20120101'
end = '20231231'
match_type = 'm'

# %%
start_date = datetime.strptime(start, '%Y%m%d').date()
end_date = datetime.strptime(end, '%Y%m%d').date()

# if match_type == 'm':   
#     typer = MensTennisMatch
#     insert_db = MensTennisMatchStats
# else:
#     typer = WomensTennisMatch
#     insert_db = WomensTennisMatchStats

# query = insert_db.objects.filter(
#         tourney_date__range=(start_date, end_date)
#     ).order_by('tourney_date')
    
# games = await sync_to_async(list)(query.all().values())

RD_CUTOFF = 150

# df = pd.read_csv('../../testcsvs/GLICKO6.040.csv')
df = pd.read_csv('../../testcsvs/StephFixRP25.csv')

print(df.columns)
df['tourney_date'] = pd.to_datetime(df['tourney_date']).dt.date
df = df[(df['tourney_date'] >= start_date) & (df['tourney_date'] <= end_date)]
# df = df[(df['a_glicko_rd'] <= RD_CUTOFF) & (df['b_glicko_rd'] <= RD_CUTOFF)]
df = df[(df['a_steph_rd'] <= RD_CUTOFF) & (df['b_steph_rd'] <= RD_CUTOFF)]

df = df.drop(['tourney_id', 'tourney_name', 'match_num', 'tourney_date', 'a_player_name', 'b_player_name', 'a_player_id', 'a_player_slug', 'b_player_id', 'b_player_slug', 'sets', 'games', 'tiebreaks'], axis=1)
# print(df.duplicated().sum())

print(len(df))

one_hot_encoder = OneHotEncoder(sparse_output=False)

# One-Hot Encode the 'category_text' column
category_encoded = one_hot_encoder.fit_transform(df[['surface']])

# Convert to DataFrame
category_encoded_df = pd.DataFrame(category_encoded, columns=one_hot_encoder.get_feature_names_out(['surface']))

# Concatenate the one-hot encoded columns back to the original DataFrame
df = pd.concat([df.reset_index(drop=True), category_encoded_df], axis=1)

# Drop the original 'category_text' column
df.drop('surface', axis=1, inplace=True)
# print(df.duplicated().sum())

print(len(df))
# Out:
# Index(['tourney_id', 'tourney_name', 'tourney_date', 'surface', 'best_of',
#        'match_num', 'tourney_level', 'tourney_round', 'a_player_id',
#        'a_player_name',
#        ...
#        'a_surface_return_second_won_steph_rating',
#        'b_surface_second_won_steph_rating',
#        'a_surface_return_second_won_steph_rd', 'b_surface_second_won_steph_rd',
#        'sets', 'games', 'tiebreaks', 'a_odds', 'b_odds', 'a_b_win'],
#       dtype='object', length=174)
# 28428
# 28428

# %%
df.head()
# Out:
#    best_of  tourney_level  tourney_round  a_player_age  a_player_hand  \
# 0      3.0            2.0            0.8          23.0            1.0
# 1      3.0            2.0            0.8          28.0            1.0
# 2      3.0            2.0            0.8          23.0            1.0
# 3      3.0            2.0            0.8          24.0            1.0
# 4      3.0            2.0            0.8          26.0            1.0
#
#    a_player_ht  a_player_rank  a_player_rank_points  b_player_age  \
# 0        180.0           15.0                1925.0          28.0
# 1        188.0           65.0                 755.0          25.0
# 2        183.0           89.0                 612.0          22.0
# 3        178.0           48.0                 915.0          26.0
# 4        196.0           70.0                 693.0          25.0
#
#    b_player_hand  ...  a_surface_return_second_won_steph_rating  \
# 0            0.0  ...                               2214.527572
# 1            1.0  ...                               2212.082683
# 2            1.0  ...                               2192.204097
# 3            1.0  ...                               2204.616997
# 4            1.0  ...                               2170.614312
#
#    b_surface_second_won_steph_rating  a_surface_return_second_won_steph_rd  \
# 0                        2200.503515                             60.921102
# 1                        2195.126051                             61.967452
# 2                        2221.788831                             78.900391
# 3                        2199.926824                             63.764441
# 4                        2201.271946                             80.399278
#
#    b_surface_second_won_steph_rd  a_odds  b_odds  a_b_win  surface_Clay  \
# 0                      65.322681    1.28    3.59      1.0           0.0
# 1                      70.349421     NaN     NaN      1.0           0.0
# 2                      83.442883    2.29    1.59      0.0           0.0
# 3                      65.658069    2.40    1.54      0.0           0.0
# 4                      61.103138    4.44    1.19      0.0           0.0
#
#    surface_Grass  surface_Hard
# 0            0.0           1.0
# 1            0.0           1.0
# 2            0.0           1.0
# 3            0.0           1.0
# 4            0.0           1.0
#
# [5 rows x 163 columns]

# %%
import sqlite3
import time
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint

df = df[(df['tourney_level'] == 6.0)]

earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
mcp_save = ModelCheckpoint('Trained-Model-ML.keras', save_best_only=True, monitor='val_loss', mode='min')

df = df.dropna()

margin = df['a_b_win']
df = df.drop(columns=['a_b_win', 'a_odds', 'b_odds'])

data = df.values
data = data.astype(float)

x_train = tf.keras.utils.normalize(data, axis=1)
y_train = np.asarray(margin)

model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='silu'),
    tf.keras.layers.Dense(256, activation='silu'),
    tf.keras.layers.Dense(128, activation='silu'),
    tf.keras.layers.Dense(2, activation='softmax')
])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Model training
history = model.fit(x_train, y_train, epochs=100, validation_split=0.1, batch_size=32, callbacks=[earlyStopping, mcp_save])

# Print final accuracy
train_accuracy = history.history['accuracy'][-1]
val_accuracy = history.history['val_accuracy'][-1]
print(f"Final Training Accuracy: {train_accuracy:.4f}")
print(f"Final Validation Accuracy: {val_accuracy:.4f}")

print('Done')
# Out:
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6590 - loss: 0.6085 - val_accuracy: 0.7084 - val_loss: 0.5704
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7332 - loss: 0.5371 - val_accuracy: 0.6522 - val_loss: 0.5921
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7124 - loss: 0.5529 - val_accuracy: 0.7238 - val_loss: 0.5497
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7312 - loss: 0.5201 - val_accuracy: 0.7008 - val_loss: 0.5710
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7296 - loss: 0.5364 - val_accuracy: 0.7059 - val_loss: 0.5648
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7360 - loss: 0.5319 - val_accuracy: 0.7161 - val_loss: 0.5450
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7446 - loss: 0.5317 - val_accuracy: 0.7263 - val_loss: 0.5487
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7284 - loss: 0.5378 - val_accuracy: 0.7212 - val_loss: 0.5476
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7301 - loss: 0.5406 - val_accuracy: 0.7161 - val_loss: 0.5441
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7413 - loss: 0.5200 - val_accuracy: 0.7008 - val_loss: 0.5552
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7349 - loss: 0.5277 - val_accuracy: 0.7212 - val_loss: 0.5430
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7433 - loss: 0.5313 - val_accuracy: 0.7315 - val_loss: 0.5438
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7358 - loss: 0.5362 - val_accuracy: 0.7212 - val_loss: 0.5459
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7340 - loss: 0.5345 - val_accuracy: 0.7315 - val_loss: 0.5492
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7479 - loss: 0.5150 - val_accuracy: 0.7263 - val_loss: 0.5427
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7313 - loss: 0.5313 - val_accuracy: 0.7161 - val_loss: 0.5537
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7411 - loss: 0.5311 - val_accuracy: 0.7187 - val_loss: 0.5516
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7437 - loss: 0.5237 - val_accuracy: 0.7161 - val_loss: 0.5477
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7333 - loss: 0.5262 - val_accuracy: 0.7289 - val_loss: 0.5514
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7204 - loss: 0.5390 - val_accuracy: 0.7289 - val_loss: 0.5500
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7460 - loss: 0.5197 - val_accuracy: 0.7212 - val_loss: 0.5464
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7302 - loss: 0.5461 - val_accuracy: 0.7238 - val_loss: 0.5439
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.5259 - val_accuracy: 0.7212 - val_loss: 0.5456
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7444 - loss: 0.5240 - val_accuracy: 0.7263 - val_loss: 0.5410
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7198 - loss: 0.5377 - val_accuracy: 0.7340 - val_loss: 0.5415
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7294 - loss: 0.5444 - val_accuracy: 0.7033 - val_loss: 0.5506
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7277 - loss: 0.5378 - val_accuracy: 0.7263 - val_loss: 0.5475
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7259 - loss: 0.5442 - val_accuracy: 0.7238 - val_loss: 0.5482
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7245 - loss: 0.5351 - val_accuracy: 0.7238 - val_loss: 0.5453
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7341 - loss: 0.5316 - val_accuracy: 0.7315 - val_loss: 0.5417
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7323 - loss: 0.5297 - val_accuracy: 0.7238 - val_loss: 0.5412
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7436 - loss: 0.5407 - val_accuracy: 0.7238 - val_loss: 0.5482
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7330 - loss: 0.5357 - val_accuracy: 0.7289 - val_loss: 0.5480
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7325 - loss: 0.5376 - val_accuracy: 0.7289 - val_loss: 0.5477
# Final Training Accuracy: 0.7405
# Final Validation Accuracy: 0.7289
# Done
