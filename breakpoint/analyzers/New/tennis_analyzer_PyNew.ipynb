# %% [markdown]
# <h1 style="text-align: center;">Tennis Analyzer ML Model V2</h1>
# <h3 style="text-align: center;">Dan Warnick</h3>

# %% [markdown]
# <p>To start we will begin by selecting the data points we want to analyze with existing known results. For each data entry we will have two players each with the following data entries.</p>
# <table style="font-size: .8em;">
#     <tr>
#         <th>Player Name</th>
#     </tr>
# </table>
# <p>Along with match facts like Clay/Hard/Grass Court or Indoor/Outdoor. In the future may want to add weather and adjust certain parameters for more accuracy and more data points to train from, however for now this seems a good start.</p>

# %% [markdown]
# <h2>1.) Collect Data Efficiently</h2>

# %%
import django
from django.http import HttpResponse
from django.template import loader
import os
from django.db import models
import torch
from math import ceil, floor
import math
import numpy as np
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as data
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.utils as utils
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.notebook import tqdm
from datetime import datetime
from asgiref.sync import sync_to_async # type: ignore
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.metrics import roc_curve, roc_auc_score
import copy
import joblib

# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'breakpoint.settings')
# django.setup()

# from render.models import *

# %%
start = '20120101'
end = '20231231'
match_type = 'm'

# %%
start_date = datetime.strptime(start, '%Y%m%d').date()
end_date = datetime.strptime(end, '%Y%m%d').date()

# if match_type == 'm':   
#     typer = MensTennisMatch
#     insert_db = MensTennisMatchStats
# else:
#     typer = WomensTennisMatch
#     insert_db = WomensTennisMatchStats

# query = insert_db.objects.filter(
#         tourney_date__range=(start_date, end_date)
#     ).order_by('tourney_date')
    
# games = await sync_to_async(list)(query.all().values())

RD_CUTOFF = 125

# df = pd.read_csv('../../testcsvs/GlickoTempTau6.0.csv')
df = pd.read_csv('../../testcsvs/StephFixRP25.csv')

print(df.columns)
df['tourney_date'] = pd.to_datetime(df['tourney_date']).dt.date
df = df[(df['tourney_date'] >= start_date) & (df['tourney_date'] <= end_date)]
# df = df[(df['a_glicko_rd'] <= RD_CUTOFF) & (df['b_glicko_rd'] <= RD_CUTOFF)]
df = df[(df['a_steph_rd'] <= RD_CUTOFF) & (df['b_steph_rd'] <= RD_CUTOFF)]


df = df.drop(['tourney_id', 'tourney_name', 'match_num', 'tourney_date', 'a_player_name', 'b_player_name', 'a_player_id', 'a_player_slug', 'b_player_id', 'b_player_slug', 'sets', 'games', 'tiebreaks'], axis=1)
# print(df.duplicated().sum())

print(len(df))

one_hot_encoder = OneHotEncoder(sparse_output=False)

# One-Hot Encode the 'category_text' column
category_encoded = one_hot_encoder.fit_transform(df[['surface']])

# Convert to DataFrame
category_encoded_df = pd.DataFrame(category_encoded, columns=one_hot_encoder.get_feature_names_out(['surface']))

# Concatenate the one-hot encoded columns back to the original DataFrame
df = pd.concat([df.reset_index(drop=True), category_encoded_df], axis=1)

# Drop the original 'category_text' column
df.drop('surface', axis=1, inplace=True)
# print(df.duplicated().sum())

print(len(df))
# Out:
# Index(['tourney_id', 'tourney_name', 'tourney_date', 'surface', 'best_of',
#        'match_num', 'tourney_level', 'tourney_round', 'a_player_id',
#        'a_player_name',
#        ...
#        'a_surface_return_second_won_steph_rating',
#        'b_surface_second_won_steph_rating',
#        'a_surface_return_second_won_steph_rd', 'b_surface_second_won_steph_rd',
#        'sets', 'games', 'tiebreaks', 'a_odds', 'b_odds', 'a_b_win'],
#       dtype='object', length=174)
# 27357
# 27357

# %%
df.head()
# Out:
#    best_of  tourney_level  tourney_round  a_player_age  a_player_hand  \
# 0      3.0            2.0            0.8          23.0            1.0
# 1      3.0            2.0            0.8          28.0            1.0
# 2      3.0            2.0            0.8          23.0            1.0
# 3      3.0            2.0            0.8          24.0            1.0
# 4      3.0            2.0            0.8          26.0            1.0
#
#    a_player_ht  a_player_rank  a_player_rank_points  b_player_age  \
# 0        180.0           15.0                1925.0          28.0
# 1        188.0           65.0                 755.0          25.0
# 2        183.0           89.0                 612.0          22.0
# 3        178.0           48.0                 915.0          26.0
# 4        196.0           70.0                 693.0          25.0
#
#    b_player_hand  ...  a_surface_return_second_won_steph_rating  \
# 0            0.0  ...                               2214.527572
# 1            1.0  ...                               2212.082683
# 2            1.0  ...                               2192.204097
# 3            1.0  ...                               2204.616997
# 4            1.0  ...                               2170.614312
#
#    b_surface_second_won_steph_rating  a_surface_return_second_won_steph_rd  \
# 0                        2200.503515                             60.921102
# 1                        2195.126051                             61.967452
# 2                        2221.788831                             78.900391
# 3                        2199.926824                             63.764441
# 4                        2201.271946                             80.399278
#
#    b_surface_second_won_steph_rd  a_odds  b_odds  a_b_win  surface_Clay  \
# 0                      65.322681    1.28    3.59      1.0           0.0
# 1                      70.349421     NaN     NaN      1.0           0.0
# 2                      83.442883    2.29    1.59      0.0           0.0
# 3                      65.658069    2.40    1.54      0.0           0.0
# 4                      61.103138    4.44    1.19      0.0           0.0
#
#    surface_Grass  surface_Hard
# 0            0.0           1.0
# 1            0.0           1.0
# 2            0.0           1.0
# 3            0.0           1.0
# 4            0.0           1.0
#
# [5 rows x 163 columns]

# %%
# Data preprocessing
df = df[df['tourney_level'] == 6.0]
df = df.dropna()

margin = df['a_b_win'].values.astype(int)
df = df.drop(columns=['a_b_win', 'a_odds', 'b_odds', 'a_b_win'])

data = df.values.astype(float)

# Normalize features
scaler = StandardScaler()
data = scaler.fit_transform(data)

# Train-test split
x_train, x_val, y_train, y_val = train_test_split(data, margin, test_size=0.1, random_state=42)

# Convert to PyTorch tensors
x_train = torch.tensor(x_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)
x_val = torch.tensor(x_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.long)

# Define the PyTorch model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(x_train.shape[1], 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 2)
        self.relu = nn.SiLU() #hehe
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.flatten(x)
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.fc4(x)  # Softmax is applied in the loss function
        return x

# Model, loss, and optimizer
model = NeuralNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 100
batch_size = 32
train_size = x_train.shape[0]

for epoch in range(epochs):
    model.train()
    for i in range(0, train_size, batch_size):
        # Batch data
        x_batch = x_train[i:i + batch_size]
        y_batch = y_train[i:i + batch_size]

        # Forward pass
        outputs = model(x_batch)
        loss = criterion(outputs, y_batch)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Evaluate on validation data
    model.eval()
    with torch.no_grad():
        val_outputs = model(x_val)
        val_loss = criterion(val_outputs, y_val)
        val_preds = torch.argmax(val_outputs, dim=1)
        val_accuracy = (val_preds == y_val).float().mean().item()

    # Print progress
    print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f}, Val Accuracy: {val_accuracy:.4f}")

print("Training complete")
# Out:
# Epoch 1/100, Loss: 0.4769, Val Loss: 0.5056, Val Accuracy: 0.7347
# Epoch 2/100, Loss: 0.4730, Val Loss: 0.5058, Val Accuracy: 0.7454
# Epoch 3/100, Loss: 0.4648, Val Loss: 0.5063, Val Accuracy: 0.7427
# Epoch 4/100, Loss: 0.4592, Val Loss: 0.5046, Val Accuracy: 0.7560
# Epoch 5/100, Loss: 0.4325, Val Loss: 0.5034, Val Accuracy: 0.7639
# Epoch 6/100, Loss: 0.4164, Val Loss: 0.5056, Val Accuracy: 0.7560
# Epoch 7/100, Loss: 0.4027, Val Loss: 0.5097, Val Accuracy: 0.7427
# Epoch 8/100, Loss: 0.3982, Val Loss: 0.5179, Val Accuracy: 0.7454
# Epoch 9/100, Loss: 0.4055, Val Loss: 0.5250, Val Accuracy: 0.7347
# Epoch 10/100, Loss: 0.3966, Val Loss: 0.5190, Val Accuracy: 0.7454
# Epoch 11/100, Loss: 0.4100, Val Loss: 0.5304, Val Accuracy: 0.7347
# Epoch 12/100, Loss: 0.4043, Val Loss: 0.5259, Val Accuracy: 0.7401
# Epoch 13/100, Loss: 0.3832, Val Loss: 0.5296, Val Accuracy: 0.7347
# Epoch 14/100, Loss: 0.3721, Val Loss: 0.5300, Val Accuracy: 0.7268
# Epoch 15/100, Loss: 0.3642, Val Loss: 0.5439, Val Accuracy: 0.7029
# Epoch 16/100, Loss: 0.3367, Val Loss: 0.5862, Val Accuracy: 0.7188
# Epoch 17/100, Loss: 0.3332, Val Loss: 0.6405, Val Accuracy: 0.7029
# Epoch 18/100, Loss: 0.2315, Val Loss: 0.7001, Val Accuracy: 0.6897
# Epoch 19/100, Loss: 0.3424, Val Loss: 0.7793, Val Accuracy: 0.6976
# Epoch 20/100, Loss: 0.2159, Val Loss: 0.8943, Val Accuracy: 0.7109
# Epoch 21/100, Loss: 0.1853, Val Loss: 1.0217, Val Accuracy: 0.6897
# Epoch 22/100, Loss: 0.1922, Val Loss: 0.9743, Val Accuracy: 0.6870
# Epoch 23/100, Loss: 0.2075, Val Loss: 1.0287, Val Accuracy: 0.6870
# Epoch 24/100, Loss: 0.1292, Val Loss: 1.2697, Val Accuracy: 0.6817
# Epoch 25/100, Loss: 0.3123, Val Loss: 1.4746, Val Accuracy: 0.6950
# Epoch 26/100, Loss: 0.0633, Val Loss: 1.5430, Val Accuracy: 0.6950
# Epoch 27/100, Loss: 0.1358, Val Loss: 1.6964, Val Accuracy: 0.6684
# Epoch 28/100, Loss: 0.0666, Val Loss: 1.9157, Val Accuracy: 0.6844
# Epoch 29/100, Loss: 0.0375, Val Loss: 1.8562, Val Accuracy: 0.6790
# Epoch 30/100, Loss: 0.0478, Val Loss: 1.8794, Val Accuracy: 0.7162
# Epoch 31/100, Loss: 0.0747, Val Loss: 1.8164, Val Accuracy: 0.6844
# Epoch 32/100, Loss: 0.0213, Val Loss: 2.3337, Val Accuracy: 0.7056
# Epoch 33/100, Loss: 0.2364, Val Loss: 1.8451, Val Accuracy: 0.6897
# Epoch 34/100, Loss: 0.0611, Val Loss: 1.8377, Val Accuracy: 0.6684
# Epoch 35/100, Loss: 0.0243, Val Loss: 2.1474, Val Accuracy: 0.6711
# Epoch 36/100, Loss: 0.0154, Val Loss: 2.1126, Val Accuracy: 0.6764
# Epoch 37/100, Loss: 0.0045, Val Loss: 2.3573, Val Accuracy: 0.6870
# Epoch 38/100, Loss: 0.0244, Val Loss: 2.6601, Val Accuracy: 0.6844
# Epoch 39/100, Loss: 0.0033, Val Loss: 2.7344, Val Accuracy: 0.6950
# Epoch 40/100, Loss: 0.0035, Val Loss: 2.7427, Val Accuracy: 0.6950
# Epoch 41/100, Loss: 0.0022, Val Loss: 2.6293, Val Accuracy: 0.6870
# Epoch 42/100, Loss: 0.0046, Val Loss: 2.2241, Val Accuracy: 0.6976
# Epoch 43/100, Loss: 0.0194, Val Loss: 2.1800, Val Accuracy: 0.7029
# Epoch 44/100, Loss: 0.0008, Val Loss: 2.3143, Val Accuracy: 0.6844
# Epoch 45/100, Loss: 0.0004, Val Loss: 2.4662, Val Accuracy: 0.7029
# Epoch 46/100, Loss: 0.0544, Val Loss: 2.4619, Val Accuracy: 0.6578
# Epoch 47/100, Loss: 0.1281, Val Loss: 2.7199, Val Accuracy: 0.6737
# Epoch 48/100, Loss: 0.0095, Val Loss: 2.7494, Val Accuracy: 0.6711
# Epoch 49/100, Loss: 0.0054, Val Loss: 2.4407, Val Accuracy: 0.6764
# Epoch 50/100, Loss: 0.0011, Val Loss: 2.4502, Val Accuracy: 0.7029
# Epoch 51/100, Loss: 0.0026, Val Loss: 2.6121, Val Accuracy: 0.7082
# Epoch 52/100, Loss: 0.0039, Val Loss: 2.5827, Val Accuracy: 0.6923
# Epoch 53/100, Loss: 0.0003, Val Loss: 2.8241, Val Accuracy: 0.6950
# Epoch 54/100, Loss: 0.0003, Val Loss: 2.8787, Val Accuracy: 0.6923
# Epoch 55/100, Loss: 0.0064, Val Loss: 2.5123, Val Accuracy: 0.7109
# Epoch 56/100, Loss: 0.0009, Val Loss: 2.6222, Val Accuracy: 0.6790
# Epoch 57/100, Loss: 0.0655, Val Loss: 2.4253, Val Accuracy: 0.6711
# Epoch 58/100, Loss: 0.0074, Val Loss: 2.5488, Val Accuracy: 0.6578
# Epoch 59/100, Loss: 0.0187, Val Loss: 2.3538, Val Accuracy: 0.6472
# Epoch 60/100, Loss: 0.0148, Val Loss: 2.4600, Val Accuracy: 0.6525
# Epoch 61/100, Loss: 0.0729, Val Loss: 2.6409, Val Accuracy: 0.6897
# Epoch 62/100, Loss: 0.0216, Val Loss: 2.6226, Val Accuracy: 0.6525
# Epoch 63/100, Loss: 0.0007, Val Loss: 3.0475, Val Accuracy: 0.6790
# Epoch 64/100, Loss: 0.0046, Val Loss: 2.8803, Val Accuracy: 0.6790
# Epoch 65/100, Loss: 0.0017, Val Loss: 2.7443, Val Accuracy: 0.6976
# Epoch 66/100, Loss: 0.0122, Val Loss: 2.8128, Val Accuracy: 0.7056
# Epoch 67/100, Loss: 0.0018, Val Loss: 2.8082, Val Accuracy: 0.6870
# Epoch 68/100, Loss: 0.0298, Val Loss: 2.6868, Val Accuracy: 0.6737
# Epoch 69/100, Loss: 0.0113, Val Loss: 2.3764, Val Accuracy: 0.6658
# Epoch 70/100, Loss: 0.0750, Val Loss: 2.5499, Val Accuracy: 0.7082
# Epoch 71/100, Loss: 0.0011, Val Loss: 2.8609, Val Accuracy: 0.6950
# Epoch 72/100, Loss: 0.0090, Val Loss: 2.8612, Val Accuracy: 0.7003
# Epoch 73/100, Loss: 0.0009, Val Loss: 2.8986, Val Accuracy: 0.7003
# Epoch 74/100, Loss: 0.0004, Val Loss: 2.9536, Val Accuracy: 0.6976
# Epoch 75/100, Loss: 0.0004, Val Loss: 2.9360, Val Accuracy: 0.6976
# Epoch 76/100, Loss: 0.0003, Val Loss: 2.9962, Val Accuracy: 0.7003
# Epoch 77/100, Loss: 0.0002, Val Loss: 3.0304, Val Accuracy: 0.7029
# Epoch 78/100, Loss: 0.0002, Val Loss: 3.0628, Val Accuracy: 0.7056
# Epoch 79/100, Loss: 0.0002, Val Loss: 3.0928, Val Accuracy: 0.7056
# Epoch 80/100, Loss: 0.0001, Val Loss: 3.1210, Val Accuracy: 0.7082
# Epoch 81/100, Loss: 0.0001, Val Loss: 3.1479, Val Accuracy: 0.7056
# Epoch 82/100, Loss: 0.0001, Val Loss: 3.1735, Val Accuracy: 0.7056
# Epoch 83/100, Loss: 0.0001, Val Loss: 3.1982, Val Accuracy: 0.7056
# Epoch 84/100, Loss: 0.0001, Val Loss: 3.2220, Val Accuracy: 0.7056
# Epoch 85/100, Loss: 0.0001, Val Loss: 3.2451, Val Accuracy: 0.7056
# Epoch 86/100, Loss: 0.0001, Val Loss: 3.2676, Val Accuracy: 0.7056
# Epoch 87/100, Loss: 0.0001, Val Loss: 3.2897, Val Accuracy: 0.7082
# Epoch 88/100, Loss: 0.0001, Val Loss: 3.3114, Val Accuracy: 0.7056
# Epoch 89/100, Loss: 0.0001, Val Loss: 3.3330, Val Accuracy: 0.7056
# Epoch 90/100, Loss: 0.0000, Val Loss: 3.3543, Val Accuracy: 0.7056
# Epoch 91/100, Loss: 0.0000, Val Loss: 3.3753, Val Accuracy: 0.7029
# Epoch 92/100, Loss: 0.0000, Val Loss: 3.3961, Val Accuracy: 0.7003
# Epoch 93/100, Loss: 0.0000, Val Loss: 3.4165, Val Accuracy: 0.7003
# Epoch 94/100, Loss: 0.0000, Val Loss: 3.4367, Val Accuracy: 0.7003
# Epoch 95/100, Loss: 0.0000, Val Loss: 3.4567, Val Accuracy: 0.7003
# Epoch 96/100, Loss: 0.0000, Val Loss: 3.4765, Val Accuracy: 0.7003
# Epoch 97/100, Loss: 0.0000, Val Loss: 3.4962, Val Accuracy: 0.7003
# Epoch 98/100, Loss: 0.0000, Val Loss: 3.5155, Val Accuracy: 0.7003
# Epoch 99/100, Loss: 0.0000, Val Loss: 3.5347, Val Accuracy: 0.6976
# Epoch 100/100, Loss: 0.0000, Val Loss: 3.5542, Val Accuracy: 0.6950
# Training complete
